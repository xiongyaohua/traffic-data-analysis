# %% [markdown]
# ### 题1： 有数据点
# ```
# 1 2 3 4 5 6 7 8
# 1 3 3 4 6 6 4 8
# ```
# 其中(2,3) (5,6) (7,4)是训练集，其余点为测试集
#
# - 在训练集上拟合模型1 $y=ax+b$
# - 在训练集上拟合模型2 $y=ax^2+bx+c$
# - 计算模型1,2在训练集上的均方差
# - 计算模型1,2在测试集上的均方差
# - 比较几个均方差的大小，说明意义（提示：过拟合）
#
# ### 题目2：已知某国空军战斗机从1开始连续编号，总数量N未知但不超过10架。试利用贝叶斯概率估计N。
# - 用文字描述本问题的假说H。写出该假说先验概率分布
# - 计算先验概率分布的期望值
# - 某间谍偶然看到一架编号为4号的飞机，写出该数据对应的似然概率分布（提示：$P(4|N=3)$，空军只有3架飞机时间谍看到4号飞机的概率是多少？N等于其他值呢？）
# - 写出后验概率分布的期望值
#
#
# ### 题目3：解释支持向量机的工作机制
# - 写出支持向量机带约束的优化模型，并分别解释目标函数和约束条件的意义
# - 解释svm中“软边界”和“硬边界”两个概念，以及什么情况下需要软边界
# - 解释svm中核方法的概念，以及什么情况下需要核方法
#
# ### 题目4：从几何投影角度推导最小二乘法公式$A^TA=A^Ty$
# - 假设$A$由为两个三维列向量$\vec{a}_1,\vec{a}_2$ 组成，画出$a_1,a_2,y$三个向量
# - 画出$y$对$a_1,a_2$张开平面的投影点$y^*$
# - 标出从$y$到$y^*$的投影向量$e$
# - 利用$e$与$a_1,a_2$垂直的性质推导$A^TA=A^Ty$
